# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from functools import reduce
import os
import warnings

# %%
# set directory
os.chdir('/Users/shreyad/Library/CloudStorage/OneDrive-HarvardUniversity/DS Final Project/1. Data')
#os.chdir('/Users/seharnoor/Library/CloudStorage/OneDrive-HarvardUniversity/Fall 2023/CS 109A/DS Final Project/1. Data')
#print(os.getcwd())

# ignore warnings for a clean file
warnings.filterwarnings('ignore')

# %%
# Load files with low_memory=False
ACS_2019 = pd.read_csv("3. US Census/ACSDP1Y2019.DP05-Data.csv", low_memory=False)
ACS_2021 = pd.read_csv("3. US Census/ACSDP1Y2021.DP05-Data.csv", low_memory=False)
ACS_2022 = pd.read_csv("3. US Census/ACSDP1Y2022.DP05-Data.csv", low_memory=False)

# %%
# Add suffixes to columns
ACS_2019['year'] = 2019
ACS_2021['year'] = 2021
ACS_2022['year'] = 2022

# append all data together
appended_acs_data = pd.concat([ACS_2019, ACS_2021, ACS_2022])

# %%
appended_acs_data.head()
# Out:
#            GEO_ID                     NAME  \
# 0       Geography     Geographic Area Name
# 1  0500000US01003  Baldwin County, Alabama
# 2  0500000US01015  Calhoun County, Alabama
# 3  0500000US01043  Cullman County, Alabama
# 4  0500000US01049   DeKalb County, Alabama
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                   223234
# 2                                   113605
# 3                                    83768
# 4                                    71513
#
#                                          DP05_0001EA  \
# 0  Annotation of Estimate!!SEX AND AGE!!Total pop...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                           *****
# 2                                           *****
# 3                                           *****
# 4                                           *****
#
#                                          DP05_0001MA  \
# 0  Annotation of Margin of Error!!SEX AND AGE!!To...
# 1                                              *****
# 2                                              *****
# 3                                              *****
# 4                                              *****
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                         109192
# 2                                          54285
# 3                                          40579
# 4                                          35688
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               1466
# 2                                                701
# 3                                                905
# 4                                                884
#
#                                          DP05_0002MA  \
# 0  Annotation of Margin of Error!!SEX AND AGE!!To...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          DP05_0002EA  ... DP05_0091MA  \
# 0  Annotation of Estimate!!SEX AND AGE!!Total pop...  ...         NaN
# 1                                                NaN  ...         NaN
# 2                                                NaN  ...         NaN
# 3                                                NaN  ...         NaN
# 4                                                NaN  ...         NaN
#
#   DP05_0090PE DP05_0090PEA DP05_0090PM DP05_0090PMA DP05_0091PE DP05_0091PEA  \
# 0         NaN          NaN         NaN          NaN         NaN          NaN
# 1         NaN          NaN         NaN          NaN         NaN          NaN
# 2         NaN          NaN         NaN          NaN         NaN          NaN
# 3         NaN          NaN         NaN          NaN         NaN          NaN
# 4         NaN          NaN         NaN          NaN         NaN          NaN
#
#   DP05_0091PM DP05_0091PMA Unnamed: 730
# 0         NaN          NaN          NaN
# 1         NaN          NaN          NaN
# 2         NaN          NaN          NaN
# 3         NaN          NaN          NaN
# 4         NaN          NaN          NaN
#
# [5 rows x 733 columns]

# %%
# Get the headers from the second row, which contains the descriptive text.
descriptive_headers = appended_acs_data.iloc[0]
header_dict = descriptive_headers.to_dict()

# Filter out the columns that contain 'Estimate!!' and also include 'Geography' and 'Geographic Area Name'
estimate_columns = [col for col, desc in header_dict.items() if "Estimate!!" in str(desc) and not desc.startswith("Annotation of Estimate!!")]

# Include 'GEO_ID' and 'NAME' columns which might not contain 'Estimate!!'
estimate_columns.extend(['GEO_ID', 'NAME', 'year'])

# %%
filtered_ACS = appended_acs_data[estimate_columns]
filtered_ACS.head()
# Out:
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                   223234
# 2                                   113605
# 3                                    83768
# 4                                    71513
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                         109192
# 2                                          54285
# 3                                          40579
# 4                                          35688
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                           114042
# 2                                            59320
# 3                                            43189
# 4                                            35825
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1                                               95.7
# 2                                               91.5
# 3                                               94.0
# 4                                               99.6
#
#                                           DP05_0005E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Under...
# 1                                              10616
# 2                                               6699
# 3                                               5310
# 4                                               4578
#
#                                           DP05_0006E  \
# 0  Estimate!!SEX AND AGE!!Total population!!5 to ...
# 1                                              12826
# 2                                               5534
# 3                                               4563
# 4                                               4292
#
#                                           DP05_0007E  \
# 0  Estimate!!SEX AND AGE!!Total population!!10 to...
# 1                                              14373
# 2                                               7774
# 3                                               5906
# 4                                               5519
#
#                                           DP05_0008E  \
# 0  Estimate!!SEX AND AGE!!Total population!!15 to...
# 1                                              14410
# 2                                               7541
# 3                                               4591
# 4                                               5128
#
#                                           DP05_0009E  \
# 0  Estimate!!SEX AND AGE!!Total population!!20 to...
# 1                                              11292
# 2                                               6973
# 3                                               4603
# 4                                               4989
#
#                                           DP05_0010E  ...  \
# 0  Estimate!!SEX AND AGE!!Total population!!25 to...  ...
# 1                                              24401  ...
# 2                                              14981  ...
# 3                                              10588  ...
# 4                                               8436  ...
#
#                                           DP05_0083E  \
# 0  Estimate!!HISPANIC OR LATINO AND RACE!!Total p...
# 1                                               4711
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#                                           DP05_0084E  \
# 0  Estimate!!HISPANIC OR LATINO AND RACE!!Total p...
# 1                                                  0
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#                                           DP05_0085E  \
# 0  Estimate!!HISPANIC OR LATINO AND RACE!!Total p...
# 1                                               4711
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#                       DP05_0086E  \
# 0  Estimate!!Total housing units
# 1                         119425
# 2                          53809
# 3                          38256
# 4                          31606
#
#                                           DP05_0087E  \
# 0  Estimate!!CITIZEN, VOTING AGE POPULATION!!Citi...
# 1                                             171344
# 2                                              87872
# 3                                              63818
# 4                                              49295
#
#                                           DP05_0088E  \
# 0  Estimate!!CITIZEN, VOTING AGE POPULATION!!Citi...
# 1                                              80874
# 2                                              41162
# 3                                              30623
# 4                                              24299
#
#                                           DP05_0089E          GEO_ID  \
# 0  Estimate!!CITIZEN, VOTING AGE POPULATION!!Citi...       Geography
# 1                                              90470  0500000US01003
# 2                                              46710  0500000US01015
# 3                                              33195  0500000US01043
# 4                                              24996  0500000US01049
#
#                       NAME  year
# 0     Geographic Area Name  2019
# 1  Baldwin County, Alabama  2019
# 2  Calhoun County, Alabama  2019
# 3  Cullman County, Alabama  2019
# 4   DeKalb County, Alabama  2019
#
# [5 rows x 92 columns]

# %%
# Extract the last five characters of 'GEO_ID', ensuring it's a string and preserving leading zeros
filtered_ACS['FIPS_ID'] = filtered_ACS['GEO_ID'].astype(str).apply(lambda x: x[-5:].zfill(5))

# Reorder columns to move 'FIPS_ID' to the first position
cols = ['FIPS_ID'] + [col for col in filtered_ACS.columns if col != 'FIPS_ID']
filtered_ACS = filtered_ACS[cols]

# %%
# move, geo_id, name, year to the front of the dataset

cols_to_move = ['GEO_ID', 'NAME', 'year']
other_cols = [col for col in filtered_ACS.columns if col not in cols_to_move]
new_order = cols_to_move + other_cols
filtered_ACS = filtered_ACS[new_order]

# %%
# Select the first two rows of the dataset
first_two_rows = filtered_ACS.iloc[:1]

# Transpose the data so I can add variable names in csv
transposed_first_data = first_two_rows.transpose()
transposed_first_data.to_csv('3. US Census/transposed_data.csv', index=True)

# %%
rename_dict = {
    "DP05_0001E": "total_population",
    "DP05_0002E": "total_male_population",
    "DP05_0003E": "total_female_population",
    "DP05_0004E": "sex_ratio",
    "DP05_0005E": "under_5_pop",
    "DP05_0006E": "pop_5_9",
    "DP05_0007E": "pop_10_14",
    "DP05_0008E": "pop_15_19",
    "DP05_0009E": "pop_20_24",
    "DP05_0010E": "pop_25_34",
    "DP05_0011E": "pop_35_44",
    "DP05_0012E": "pop_45_54",
    "DP05_0013E": "pop_55_59",
    "DP05_0014E": "pop_60_64",
    "DP05_0015E": "pop_65_74",
    "DP05_0016E": "pop_75_84",
    "DP05_0017E": "pop_85_plus",
    "DP05_0018E": "median_age_total",
    "DP05_0019E": "total_pop_under_18",
    "DP05_0020E": "pop_16_and_plus",
    "DP05_0021E": "pop_18_and_plus",
    "DP05_0022E": "pop_21_and_plus",
    "DP05_0023E": "pop_62_and_plus",
    "DP05_0024E": "pop_65_and_plus",
    "DP05_0025E": "pop_18_and_plus_v2",
    "DP05_0026E": "pop_18_and_plus_male",
    "DP05_0027E": "pop_18_and_plus_female",
    "DP05_0028E": "sex_ratio_18_over",
    "DP05_0029E": "pop_65_and_plus_v2",
    "DP05_0030E": "pop_65_and_plus_male",
    "DP05_0031E": "pop_65_and_plus_female",
    "DP05_0032E": "sex_ratio_65_over",
    "DP05_0033E": "total_population_v2",
    "DP05_0034E": "total_pop_one_race",
    "DP05_0035E": "total_pop_two_more_race",
    "DP05_0036E": "total_pop_one_race_v2",
     "DP05_0037E": "total_whites",
    "DP05_0038E": "total_black_aa",
    "DP05_0039E": "total_american_indian",
    "DP05_0040E": "total_american_indian_cherokee",
    "DP05_0041E": "total_american_indian_chippewa",
    "DP05_0042E": "total_american_indian_navajo",
    "DP05_0043E": "total_american_indian_sioux",
    "DP05_0044E": "total_asian",
    "DP05_0045E": "total_asian_indian",
    "DP05_0046E": "total_asian_chinese",
    "DP05_0047E": "total_asian_filipino",
    "DP05_0048E": "total_asian_japanese",
    "DP05_0049E": "total_asian_korean",
    "DP05_0050E": "total_asian_vietnamese",
    "DP05_0051E": "total_asian_other",
    "DP05_0052E": "total_native_hawaiian_other_islander",
    "DP05_0053E": "total_native_hawaiian",
    "DP05_0054E": "total_guamanian",
    "DP05_0055E": "total_samoan",
    "DP05_0056E": "total_other_pacific_islander",
    "DP05_0057E": "total_other_race",
    "DP05_0058E": "total_pop_two_more_race_v2",
    "DP05_0059E": "total_white_black",
    "DP05_0060E": "total_white_american_indian",
    "DP05_0061E": "total_white_asian",
    "DP05_0062E": "total_black_american_indian",
    "DP05_0063E": "total_pop_comb_race",
    "DP05_0064E": "total_pop_comb_race_white",
    "DP05_0065E": "total_pop_comb_race_black",
    "DP05_0066E": "total_pop_comb_race_american_ind",
    "DP05_0067E": "total_pop_comb_race_asian",
    "DP05_0068E": "total_pop_comb_race_native_haw",
    "DP05_0069E": "total_pop_comb_race_other",
    "DP05_0070E": "total_population_hispanic",
    "DP05_0071E": "total_population_hispanic_any_race",
    "DP05_0072E": "total_population_hispanic_mex",
    "DP05_0073E": "total_population_hispanic_puerto_rico",
    "DP05_0074E": "total_population_hispanic_cuban",
    "DP05_0075E": "total_population_hispanic_other",
    "DP05_0086E": "total_housing_units",
    "DP05_0087E": "total_voting_age_pop",
    "DP05_0088E": "total_voting_age_pop_male",
    "DP05_0089E": "total_voting_age_pop_female"
}

filtered_ACS_v2 = filtered_ACS.rename(columns=rename_dict)

# %%
# drop the first row of the dataset
filtered_ACS_v2 = filtered_ACS_v2.drop(filtered_ACS_v2.index[0])

# drop columns that are not needed

columns_to_drop = [
    "DP05_0076E", "DP05_0077E", "DP05_0078E", "DP05_0079E",
    "DP05_0080E", "DP05_0081E", "DP05_0082E", "DP05_0083E",
    "DP05_0084E", "DP05_0085E"
]

filtered_ACS_v2 = filtered_ACS_v2.drop(columns=columns_to_drop, errors='ignore')

# %%
# replace all N's as missing 
filtered_ACS_v2 = filtered_ACS_v2.replace('N', np.nan)

# %%
# view dataset
filtered_ACS_v2.head()
# Out:
#            GEO_ID                     NAME  year FIPS_ID total_population  \
# 1  0500000US01003  Baldwin County, Alabama  2019   01003           223234
# 2  0500000US01015  Calhoun County, Alabama  2019   01015           113605
# 3  0500000US01043  Cullman County, Alabama  2019   01043            83768
# 4  0500000US01049   DeKalb County, Alabama  2019   01049            71513
# 5  0500000US01051   Elmore County, Alabama  2019   01051            81209
#
#   total_male_population total_female_population sex_ratio under_5_pop pop_5_9  \
# 1                109192                  114042      95.7       10616   12826
# 2                 54285                   59320      91.5        6699    5534
# 3                 40579                   43189      94.0        5310    4563
# 4                 35688                   35825      99.6        4578    4292
# 5                 40060                   41149      97.4        4272    6638
#
#    ... total_population_hispanic total_population_hispanic_any_race  \
# 1  ...                    223234                              10534
# 2  ...                    113605                               4614
# 3  ...                     83768                               3752
# 4  ...                     71513                              10775
# 5  ...                     81209                               2563
#
#   total_population_hispanic_mex total_population_hispanic_puerto_rico  \
# 1                           NaN                                   NaN
# 2                           NaN                                   NaN
# 3                           NaN                                   NaN
# 4                           NaN                                   NaN
# 5                           NaN                                   NaN
#
#   total_population_hispanic_cuban total_population_hispanic_other  \
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# 5                             NaN                             NaN
#
#   total_housing_units total_voting_age_pop total_voting_age_pop_male  \
# 1              119425               171344                     80874
# 2               53809                87872                     41162
# 3               38256                63818                     30623
# 4               31606                49295                     24299
# 5               34481                61394                     29171
#
#   total_voting_age_pop_female
# 1                       90470
# 2                       46710
# 3                       33195
# 4                       24996
# 5                       32223
#
# [5 rows x 83 columns]

# %%
# Save the DataFrame to a CSV file
filtered_ACS_v2.to_csv("7. Cleaned Datasets/analysis_filtered_ACS.csv", index=False)

# %% [markdown]
# MERGE WITH NET MIGRATION DATA

# %%
acs_dta = pd.read_csv("7. Cleaned Datasets/analysis_filtered_ACS.csv", dtype={'FIPS_ID': str})
net_migration =pd.read_csv("7. Cleaned Datasets/IRS_netmigration.csv", dtype={'fips_id': str, 'county_fips': str,  'state_fips': str}, index_col=0)
#df = pd.merge(net_migration, acs_dta, how='left', left_on='fips_id', right_on='FIPS_ID')

# %%
covid_dta = pd.read_csv("7. Cleaned Datasets/Kaggle County Data/US_counties_COVID19_health_weather_data.csv", low_memory=False)
#remove territories
covid_dta = covid_dta[covid_dta['fips'].str.isdigit()]
#fill so fips_id is 5 digits
covid_dta['fips_id'] = covid_dta['fips'].apply(str).apply(lambda x: x.zfill(5))

# %%
#The original dataset has the data in long format at different months in 2020.I take the minimum date and the maximum data and max to 2019 and 2021 respectively
date_agg = covid_dta.groupby('fips')['date'].agg(min_date='min', max_date='max').reset_index()
# Merge to get the rows corresponding to the minimum dates
min_date_rows = pd.merge(covid_dta, date_agg[['fips', 'min_date']], left_on=['fips', 'date'], right_on=['fips', 'min_date'])
min_date_rows['year'] = 2020
# Merge to get the rows corresponding to the maximum dates
max_date_rows = pd.merge(covid_dta, date_agg[['fips', 'max_date']], left_on=['fips', 'date'], right_on=['fips', 'max_date'])
max_date_rows['year'] = 2021
# Combine the min and max date rows
covid = pd.concat([min_date_rows, max_date_rows]).drop(columns=['min_date', 'max_date', 'county','state']).drop_duplicates()
covid = covid.sort_values(by=['fips', 'date'])

# %%
#MERGED DATASET
df = pd.merge(net_migration, covid, how='left', on=['fips_id', 'year'])

# %%
#Check missings
missing_share_by_year = df.groupby('year').agg(lambda x: x.isnull().mean())
missing_share_by_year = missing_share_by_year.reset_index()
missings = missing_share_by_year.melt(id_vars=['year'], var_name='column', value_name='share_missing')
missings = missings.sort_values(by='share_missing', ascending=False)

# %%
#So we can see all columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
missings
# Out:
#      year                                             column  share_missing
# 441  2021                                   mean_temp_5d_avg       1.000000
# 459  2021                                   min_temp_10d_avg       1.000000
# 439  2021                                   mean_temp_3d_avg       1.000000
# 443  2021                                  mean_temp_10d_avg       1.000000
# 445  2021                                  mean_temp_15d_avg       1.000000
# 447  2021                                    max_temp_3d_avg       1.000000
# 449  2021                                    max_temp_5d_avg       1.000000
# 451  2021                                   max_temp_10d_avg       1.000000
# 453  2021                                   max_temp_15d_avg       1.000000
# 455  2021                                    min_temp_3d_avg       1.000000
# 457  2021                                    min_temp_5d_avg       1.000000
# 461  2021                                   min_temp_15d_avg       1.000000
# 463  2021                                    dewpoint_3d_avg       1.000000
# 465  2021                                    dewpoint_5d_avg       1.000000
# 467  2021                                   dewpoint_10d_avg       1.000000
# 469  2021                                   dewpoint_15d_avg       1.000000
# 421  2021                                          wind_gust       0.896720
# 411  2021                                 sea_level_pressure       0.672366
# 172  2020                                       num_deaths_4       0.564522
# 174  2020                              infant_mortality_rate       0.564522
# 175  2021                              infant_mortality_rate       0.562805
# 173  2021                                       num_deaths_4       0.562805
# 228  2020                                      homicide_rate       0.555478
# 229  2021                                      homicide_rate       0.553733
# 214  2020                         percent_disconnected_youth       0.524870
# 215  2021                         percent_disconnected_youth       0.523029
# 410  2020                                 sea_level_pressure       0.479304
# 419  2021                                     max_wind_speed       0.440684
# 415  2021                                         visibility       0.419400
# 417  2021                                         wind_speed       0.415911
# 413  2021                                   station_pressure       0.414515
# 409  2021                                           dewpoint       0.414166
# 425  2021                                        precip_flag       0.408583
# 423  2021                                      precipitation       0.408583
# 194  2020                           num_drug_overdose_deaths       0.403478
# 196  2020                       drug_overdose_mortality_rate       0.403478
# 195  2021                           num_drug_overdose_deaths       0.401256
# 197  2021                       drug_overdose_mortality_rate       0.401256
# 407  2021                                           max_temp       0.390440
# 405  2021                                           min_temp       0.390091
# 403  2021                                          mean_temp       0.385555
# 401  2021                                       station_name       0.385555
# 399  2021                                         station_id       0.385555
# 429  2021                                               rain       0.385555
# 431  2021                                               snow       0.385555
# 433  2021                                               hail       0.385555
# 435  2021                                            thunder       0.385555
# 437  2021                                            tornado       0.385555
# 427  2021                                                fog       0.385555
# 168  2020                                       num_deaths_3       0.337739
# 170  2020                               child_mortality_rate       0.337739
# 420  2020                                          wind_gust       0.337043
# 171  2021                               child_mortality_rate       0.335311
# 169  2021                                       num_deaths_3       0.335311
# 238  2020                               juvenile_arrest_rate       0.301217
# 239  2021                               juvenile_arrest_rate       0.301117
# 224  2020                                  segregation_index       0.287652
# 225  2021                                  segregation_index       0.285764
# 182  2020                                      num_hiv_cases       0.238261
# 184  2020                                hiv_prevalence_rate       0.238261
# 183  2021                                      num_hiv_cases       0.236916
# 185  2021                                hiv_prevalence_rate       0.236916
# 234  2020                             num_firearm_fatalities       0.230609
# 236  2020                            firearm_fatalities_rate       0.230609
# 235  2021                             num_firearm_fatalities       0.227844
# 237  2021                            firearm_fatalities_rate       0.227844
# 218  2020                        average_grade_performance_2       0.194783
# 219  2021                        average_grade_performance_2       0.194696
# 216  2020                          average_grade_performance       0.183304
# 217  2021                          average_grade_performance       0.182833
# 232  2020                          suicide_rate_age_adjusted       0.180174
# 230  2020                                       num_deaths_5       0.180174
# 233  2021                          suicide_rate_age_adjusted       0.176902
# 231  2021                                       num_deaths_5       0.176902
# 470  2020                        date_stay_at_home_announced       0.165217
# 472  2020                        date_stay_at_home_effective       0.165217
# 471  2021                        date_stay_at_home_announced       0.162596
# 473  2021                        date_stay_at_home_effective       0.162596
# 412  2020                                   station_pressure       0.137043
# 422  2020                                      precipitation       0.115478
# 424  2020                                        precip_flag       0.115478
# 414  2020                                         visibility       0.089739
# 394  2020                                               CALL       0.087652
# 395  2021                                               CALL       0.086183
# 468  2020                                   dewpoint_15d_avg       0.085217
# 466  2020                                   dewpoint_10d_avg       0.082783
# 464  2020                                    dewpoint_5d_avg       0.080348
# 462  2020                                    dewpoint_3d_avg       0.078261
# 408  2020                                           dewpoint       0.077217
# 198  2020                           num_motor_vehicle_deaths       0.076522
# 200  2020                       motor_vehicle_mortality_rate       0.076522
# 199  2021                           num_motor_vehicle_deaths       0.076064
# 201  2021                       motor_vehicle_mortality_rate       0.076064
# 418  2020                                     max_wind_speed       0.054957
# 136  2020                      annual_average_violent_crimes       0.054609
# 138  2020                                 violent_crime_rate       0.054609
# 139  2021                                 violent_crime_rate       0.053385
# 137  2021                      annual_average_violent_crimes       0.053385
# 226  2020                                segregation_index_2       0.052870
# 416  2020                                         wind_speed       0.051478
# 227  2021                                segregation_index_2       0.050942
# 96   2020                        mental_health_provider_rate       0.047652
# 94   2020                        num_mental_health_providers       0.047652
# 97   2021                        mental_health_provider_rate       0.046057
# 95   2021                        num_mental_health_providers       0.046057
# 222  2020          percent_enrolled_in_free_or_reduced_lunch       0.043478
# 223  2021          percent_enrolled_in_free_or_reduced_lunch       0.042917
# 86   2020                        num_primary_care_physicians       0.038261
# 87   2021                        num_primary_care_physicians       0.037683
# 88   2020                       primary_care_physicians_rate       0.037565
# 89   2021                       primary_care_physicians_rate       0.036985
# 46   2020                                         num_deaths       0.032000
# 48   2020                  years_of_potential_life_lost_rate       0.032000
# 92   2020                                       dentist_rate       0.030261
# 90   2020                                       num_dentists       0.030261
# 47   2021                                         num_deaths       0.030007
# 49   2021                  years_of_potential_life_lost_rate       0.030007
# 91   2021                                       num_dentists       0.029658
# 93   2021                                       dentist_rate       0.029658
# 12   2020                                   log_agi_incomers       0.022957
# 10   2020                                       agi_incomers       0.022957
# 452  2020                                   max_temp_15d_avg       0.018435
# 13   2021                                   log_agi_incomers       0.018144
# 11   2021                                       agi_incomers       0.018144
# 104  2020                        high_school_graduation_rate       0.017391
# 146  2020                        presence_of_water_violation       0.017043
# 19   2021                                    log_agi_leavers       0.016748
# 105  2021                        high_school_graduation_rate       0.016748
# 147  2021                        presence_of_water_violation       0.016748
# 17   2021                                        agi_leavers       0.016748
# 450  2020                                   max_temp_10d_avg       0.014609
# 76   2020                                num_chlamydia_cases       0.013565
# 78   2020                                     chlamydia_rate       0.013565
# 18   2020                                    log_agi_leavers       0.012870
# 80   2020                                    teen_birth_rate       0.012870
# 16   2020                                        agi_leavers       0.012870
# 81   2021                                    teen_birth_rate       0.011863
# 77   2021                                num_chlamydia_cases       0.011863
# 79   2021                                     chlamydia_rate       0.011863
# 144  2020                                average_daily_pm2_5       0.010435
# 145  2021                                average_daily_pm2_5       0.010119
# 460  2020                                   min_temp_15d_avg       0.009739
# 448  2020                                    max_temp_5d_avg       0.009739
# 212  2020                   other_primary_care_provider_rate       0.009391
# 446  2020                                    max_temp_3d_avg       0.009043
# 62   2020                             food_environment_index       0.009043
# 192  2020            percent_limited_access_to_healthy_foods       0.009043
# 458  2020                                   min_temp_10d_avg       0.009043
# 190  2020                                 num_limited_access       0.009043
# 193  2021            percent_limited_access_to_healthy_foods       0.008723
# 191  2021                                 num_limited_access       0.008723
# 63   2021                             food_environment_index       0.008723
# 454  2020                                    min_temp_3d_avg       0.008696
# 456  2020                                    min_temp_5d_avg       0.008696
# 213  2021                   other_primary_care_provider_rate       0.008374
# 406  2020                                           max_temp       0.008348
# 404  2020                                           min_temp       0.008348
# 402  2020                                          mean_temp       0.008000
# 400  2020                                       station_name       0.008000
# 398  2020                                         station_id       0.008000
# 432  2020                                               hail       0.008000
# 434  2020                                            thunder       0.008000
# 428  2020                                               rain       0.008000
# 426  2020                                                fog       0.008000
# 430  2020                                               snow       0.008000
# 444  2020                                  mean_temp_15d_avg       0.008000
# 442  2020                                  mean_temp_10d_avg       0.008000
# 438  2020                                   mean_temp_3d_avg       0.008000
# 436  2020                                            tornado       0.008000
# 440  2020                                   mean_temp_5d_avg       0.008000
# 57   2021                            percent_low_birthweight       0.006281
# 56   2020                            percent_low_birthweight       0.006261
# 98   2020                   preventable_hospitalization_rate       0.006261
# 70   2020                num_alcohol_impaired_driving_deaths       0.005913
# 72   2020                                 num_driving_deaths       0.005913
# 74   2020    percent_driving_deaths_with_alcohol_involvement       0.005913
# 140  2020                                  num_injury_deaths       0.005565
# 142  2020                                  injury_death_rate       0.005565
# 99   2021                   preventable_hospitalization_rate       0.005234
# 100  2020                      percent_with_annual_mammogram       0.005217
# 102  2020                                 percent_vaccinated       0.005217
# 71   2021                num_alcohol_impaired_driving_deaths       0.004885
# 73   2021                                 num_driving_deaths       0.004885
# 75   2021    percent_driving_deaths_with_alcohol_involvement       0.004885
# 101  2021                      percent_with_annual_mammogram       0.004885
# 103  2021                                 percent_vaccinated       0.004885
# 141  2021                                  num_injury_deaths       0.004536
# 143  2021                                  injury_death_rate       0.004536
# 162  2020                                    life_expectancy       0.004522
# 164  2020                                       num_deaths_2       0.004174
# 166  2020                            age_adjusted_death_rate       0.004174
# 163  2021                                    life_expectancy       0.003838
# 288  2020                                      percent_rural       0.003478
# 286  2020                                          num_rural       0.003478
# 165  2021                                       num_deaths_2       0.003140
# 167  2021                            age_adjusted_death_rate       0.003140
# 287  2021                                          num_rural       0.003140
# 289  2021                                      percent_rural       0.003140
# 120  2020                        eightieth_percentile_income       0.003130
# 122  2020                        twentieth_percentile_income       0.003130
# 124  2020                                       income_ratio       0.003130
# 66   2020      percent_with_access_to_exercise_opportunities       0.003130
# 67   2021      percent_with_access_to_exercise_opportunities       0.002791
# 125  2021                                       income_ratio       0.002791
# 123  2021                        twentieth_percentile_income       0.002791
# 121  2021                        eightieth_percentile_income       0.002791
# 158  2020                        num_workers_who_drive_alone       0.002783
# 246  2020             num_households_with_severe_cost_burden       0.002783
# 248  2020                 percent_severe_housing_cost_burden       0.002783
# 160  2020                  percent_long_commute_drives_alone       0.002783
# 156  2020                        percent_drive_alone_to_work       0.002783
# 247  2021             num_households_with_severe_cost_burden       0.002442
# 159  2021                        num_workers_who_drive_alone       0.002442
# 157  2021                        percent_drive_alone_to_work       0.002442
# 249  2021                 percent_severe_housing_cost_burden       0.002442
# 161  2021                  percent_long_commute_drives_alone       0.002442
# 326  2020                             percent_unemployed_CDC       0.002435
# 324  2020                              percent_below_poverty       0.002435
# 338  2020                                 percent_minorities       0.002435
# 328  2020                      percent_no_highschool_diploma       0.002435
# 330  2020                           percent_age_65_and_older       0.002435
# 332  2020                         percent_age_17_and_younger       0.002435
# 334  2020                                   percent_disabled       0.002435
# 336  2020               percent_single_parent_households_CDC       0.002435
# 300  2020                          num_no_highschool_diploma       0.002435
# 322  2020            num_institutionalized_in_group_quarters       0.002435
# 320  2020                     num_households_with_no_vehicle       0.002435
# 290  2020                                  num_housing_units       0.002435
# 292  2020                                 num_households_CDC       0.002435
# 294  2020                                  num_below_poverty       0.002435
# 296  2020                                 num_unemployed_CDC       0.002435
# 342  2020                         percent_multi_unit_housing       0.002435
# 298  2020                                  per_capita_income       0.002435
# 302  2020                               num_age_65_and_older       0.002435
# 304  2020                             num_age_17_and_younger       0.002435
# 306  2020                                       num_disabled       0.002435
# 308  2020                   num_single_parent_households_CDC       0.002435
# 310  2020                                     num_minorities       0.002435
# 312  2020                      num_limited_english_abilities       0.002435
# 314  2020                             num_multi_unit_housing       0.002435
# 316  2020                                   num_mobile_homes       0.002435
# 318  2020                                   num_overcrowding       0.002435
# 340  2020                  percent_limited_english_abilities       0.002435
# 392  2020                              km_to_closest_station       0.002435
# 344  2020                               percent_mobile_homes       0.002435
# 382  2020                       percentile_rank_overcrowding       0.002435
# 386  2020  percentile_rank_institutionalized_in_group_qua...       0.002435
# 388  2020         percentile_rank_housing_and_transportation       0.002435
# 390  2020               percentile_rank_social_vulnerability       0.002435
# 396  2020                                             ELEV_M       0.002435
# 42   2020                                          area_sqmi       0.002435
# 40   2020                                   total_population       0.002435
# 38   2020                                                lon       0.002435
# 36   2020                                                lat       0.002435
# 34   2020                             stay_at_home_effective       0.002435
# 282  2020                  percent_not_proficient_in_english       0.002435
# 32   2020                             stay_at_home_announced       0.002435
# 30   2020                                             deaths       0.002435
# 28   2020                                              cases       0.002435
# 26   2020                                               fips       0.002435
# 24   2020                                               date       0.002435
# 384  2020                         percentile_rank_no_vehicle       0.002435
# 380  2020                       percentile_rank_mobile_homes       0.002435
# 346  2020                               percent_overcrowding       0.002435
# 378  2020                 percentile_rank_multi_unit_housing       0.002435
# 348  2020                                 percent_no_vehicle       0.002435
# 350  2020        percent_institutionalized_in_group_quarters       0.002435
# 352  2020                      percentile_rank_below_poverty       0.002435
# 354  2020                         percentile_rank_unemployed       0.002435
# 356  2020                  percentile_rank_per_capita_income       0.002435
# 358  2020              percentile_rank_no_highschool_diploma       0.002435
# 360  2020                percentile_rank_socioeconomic_theme       0.002435
# 362  2020                   percentile_rank_age_65_and_older       0.002435
# 364  2020                 percentile_rank_age_17_and_younger       0.002435
# 366  2020                           percentile_rank_disabled       0.002435
# 368  2020           percentile_rank_single_parent_households       0.002435
# 370  2020    percentile_rank_household_comp_disability_theme       0.002435
# 372  2020                         percentile_rank_minorities       0.002435
# 374  2020          percentile_rank_limited_english_abilities       0.002435
# 376  2020  percentile_rank_minority_status_and_language_t...       0.002435
# 284  2020                                     percent_female       0.002435
# 276  2020                             num_non_hispanic_white       0.002435
# 132  2020                                   num_associations       0.002435
# 262  2020              percent_american_indian_alaska_native       0.002435
# 206  2020                                percent_uninsured_2       0.002435
# 68   2020                         percent_excessive_drinking       0.002435
# 260  2020                  num_american_indian_alaska_native       0.002435
# 134  2020                            social_association_rate       0.002435
# 54   2020          average_number_of_mentally_unhealthy_days       0.002435
# 258  2020                                      percent_black       0.002435
# 148  2020                    percent_severe_housing_problems       0.002435
# 204  2020                                    num_uninsured_2       0.002435
# 256  2020                                          num_black       0.002435
# 150  2020                         severe_housing_cost_burden       0.002435
# 52   2020        average_number_of_physically_unhealthy_days       0.002435
# 254  2020                                percent_65_and_over       0.002435
# 152  2020                                       overcrowding       0.002435
# 202  2020                         percent_insufficient_sleep       0.002435
# 154  2020                              inadequate_facilities       0.002435
# 252  2020                  percent_less_than_18_years_of_age       0.002435
# 64   2020                        percent_physically_inactive       0.002435
# 50   2020                        percent_fair_or_poor_health       0.002435
# 250  2020                                       population_2       0.002435
# 176  2020                 percent_frequent_physical_distress       0.002435
# 178  2020                   percent_frequent_mental_distress       0.002435
# 244  2020                                 percent_homeowners       0.002435
# 188  2020                              percent_food_insecure       0.002435
# 180  2020                       percent_adults_with_diabetes       0.002435
# 242  2020                                     num_homeowners       0.002435
# 44   2020                        population_density_per_sqmi       0.002435
# 240  2020  average_traffic_volume_per_meter_of_major_road...       0.002435
# 130  2020               percent_single_parent_households_CHR       0.002435
# 186  2020                                  num_food_insecure       0.002435
# 114  2020                                        labor_force       0.002435
# 274  2020                                   percent_hispanic       0.002435
# 106  2020                                   num_some_college       0.002435
# 108  2020                                         population       0.002435
# 84   2020                                  percent_uninsured       0.002435
# 272  2020                                       num_hispanic       0.002435
# 278  2020                         percent_non_hispanic_white       0.002435
# 110  2020                               percent_some_college       0.002435
# 128  2020                                 num_households_CHR       0.002435
# 270  2020     percent_native_hawaiian_other_pacific_islander       0.002435
# 112  2020                                 num_unemployed_CHR       0.002435
# 58   2020                                    percent_smokers       0.002435
# 210  2020                                percent_uninsured_3       0.002435
# 60   2020                        percent_adults_with_obesity       0.002435
# 268  2020         num_native_hawaiian_other_pacific_islander       0.002435
# 208  2020                                    num_uninsured_3       0.002435
# 116  2020                             percent_unemployed_CHR       0.002435
# 220  2020                            median_household_income       0.002435
# 266  2020                                      percent_asian       0.002435
# 118  2020                        percent_children_in_poverty       0.002435
# 82   2020                                      num_uninsured       0.002435
# 126  2020                   num_single_parent_households_CHR       0.002435
# 264  2020                                          num_asian       0.002435
# 280  2020                      num_not_proficient_in_english       0.002435
# 39   2021                                                lon       0.002094
# 187  2021                                  num_food_insecure       0.002094
# 189  2021                              percent_food_insecure       0.002094
# 393  2021                              km_to_closest_station       0.002094
# 389  2021         percentile_rank_housing_and_transportation       0.002094
# 65   2021                        percent_physically_inactive       0.002094
# 387  2021  percentile_rank_institutionalized_in_group_qua...       0.002094
# 41   2021                                   total_population       0.002094
# 209  2021                                    num_uninsured_3       0.002094
# 203  2021                         percent_insufficient_sleep       0.002094
# 397  2021                                             ELEV_M       0.002094
# 205  2021                                    num_uninsured_2       0.002094
# 391  2021               percentile_rank_social_vulnerability       0.002094
# 207  2021                                percent_uninsured_2       0.002094
# 281  2021                      num_not_proficient_in_english       0.002094
# 153  2021                                       overcrowding       0.002094
# 37   2021                                                lat       0.002094
# 69   2021                         percent_excessive_drinking       0.002094
# 83   2021                                      num_uninsured       0.002094
# 85   2021                                  percent_uninsured       0.002094
# 107  2021                                   num_some_college       0.002094
# 109  2021                                         population       0.002094
# 111  2021                               percent_some_college       0.002094
# 113  2021                                 num_unemployed_CHR       0.002094
# 115  2021                                        labor_force       0.002094
# 117  2021                             percent_unemployed_CHR       0.002094
# 119  2021                        percent_children_in_poverty       0.002094
# 127  2021                   num_single_parent_households_CHR       0.002094
# 129  2021                                 num_households_CHR       0.002094
# 131  2021               percent_single_parent_households_CHR       0.002094
# 133  2021                                   num_associations       0.002094
# 135  2021                            social_association_rate       0.002094
# 25   2021                                               date       0.002094
# 149  2021                    percent_severe_housing_problems       0.002094
# 151  2021                         severe_housing_cost_burden       0.002094
# 27   2021                                               fips       0.002094
# 211  2021                                percent_uninsured_3       0.002094
# 29   2021                                              cases       0.002094
# 155  2021                              inadequate_facilities       0.002094
# 31   2021                                             deaths       0.002094
# 177  2021                 percent_frequent_physical_distress       0.002094
# 33   2021                             stay_at_home_announced       0.002094
# 179  2021                   percent_frequent_mental_distress       0.002094
# 181  2021                       percent_adults_with_diabetes       0.002094
# 35   2021                             stay_at_home_effective       0.002094
# 385  2021                         percentile_rank_no_vehicle       0.002094
# 59   2021                                    percent_smokers       0.002094
# 383  2021                       percentile_rank_overcrowding       0.002094
# 259  2021                                      percent_black       0.002094
# 311  2021                                     num_minorities       0.002094
# 263  2021              percent_american_indian_alaska_native       0.002094
# 313  2021                      num_limited_english_abilities       0.002094
# 315  2021                             num_multi_unit_housing       0.002094
# 261  2021                  num_american_indian_alaska_native       0.002094
# 317  2021                                   num_mobile_homes       0.002094
# 319  2021                                   num_overcrowding       0.002094
# 321  2021                     num_households_with_no_vehicle       0.002094
# 333  2021                         percent_age_17_and_younger       0.002094
# 323  2021            num_institutionalized_in_group_quarters       0.002094
# 61   2021                        percent_adults_with_obesity       0.002094
# 325  2021                              percent_below_poverty       0.002094
# 327  2021                             percent_unemployed_CDC       0.002094
# 255  2021                                percent_65_and_over       0.002094
# 329  2021                      percent_no_highschool_diploma       0.002094
# 331  2021                           percent_age_65_and_older       0.002094
# 309  2021                   num_single_parent_households_CDC       0.002094
# 265  2021                                          num_asian       0.002094
# 307  2021                                       num_disabled       0.002094
# 305  2021                             num_age_17_and_younger       0.002094
# 285  2021                                     percent_female       0.002094
# 279  2021                         percent_non_hispanic_white       0.002094
# 277  2021                             num_non_hispanic_white       0.002094
# 275  2021                                   percent_hispanic       0.002094
# 291  2021                                  num_housing_units       0.002094
# 273  2021                                       num_hispanic       0.002094
# 293  2021                                 num_households_CDC       0.002094
# 295  2021                                  num_below_poverty       0.002094
# 271  2021     percent_native_hawaiian_other_pacific_islander       0.002094
# 297  2021                                 num_unemployed_CDC       0.002094
# 299  2021                                  per_capita_income       0.002094
# 269  2021         num_native_hawaiian_other_pacific_islander       0.002094
# 301  2021                          num_no_highschool_diploma       0.002094
# 303  2021                               num_age_65_and_older       0.002094
# 267  2021                                      percent_asian       0.002094
# 253  2021                  percent_less_than_18_years_of_age       0.002094
# 257  2021                                          num_black       0.002094
# 335  2021                                   percent_disabled       0.002094
# 357  2021                  percentile_rank_per_capita_income       0.002094
# 359  2021              percentile_rank_no_highschool_diploma       0.002094
# 361  2021                percentile_rank_socioeconomic_theme       0.002094
# 251  2021                                       population_2       0.002094
# 363  2021                   percentile_rank_age_65_and_older       0.002094
# 365  2021                 percentile_rank_age_17_and_younger       0.002094
# 53   2021        average_number_of_physically_unhealthy_days       0.002094
# 367  2021                           percentile_rank_disabled       0.002094
# 369  2021           percentile_rank_single_parent_households       0.002094
# 55   2021          average_number_of_mentally_unhealthy_days       0.002094
# 371  2021    percentile_rank_household_comp_disability_theme       0.002094
# 221  2021                            median_household_income       0.002094
# 373  2021                         percentile_rank_minorities       0.002094
# 375  2021          percentile_rank_limited_english_abilities       0.002094
# 377  2021  percentile_rank_minority_status_and_language_t...       0.002094
# 283  2021                  percent_not_proficient_in_english       0.002094
# 379  2021                 percentile_rank_multi_unit_housing       0.002094
# 381  2021                       percentile_rank_mobile_homes       0.002094
# 45   2021                        population_density_per_sqmi       0.002094
# 51   2021                        percent_fair_or_poor_health       0.002094
# 243  2021                                     num_homeowners       0.002094
# 245  2021                                 percent_homeowners       0.002094
# 341  2021                  percent_limited_english_abilities       0.002094
# 339  2021                                 percent_minorities       0.002094
# 343  2021                         percent_multi_unit_housing       0.002094
# 355  2021                         percentile_rank_unemployed       0.002094
# 345  2021                               percent_mobile_homes       0.002094
# 347  2021                               percent_overcrowding       0.002094
# 241  2021  average_traffic_volume_per_meter_of_major_road...       0.002094
# 337  2021               percent_single_parent_households_CDC       0.002094
# 349  2021                                 percent_no_vehicle       0.002094
# 351  2021        percent_institutionalized_in_group_quarters       0.002094
# 43   2021                                          area_sqmi       0.002094
# 353  2021                      percentile_rank_below_poverty       0.002094
# 5    2021                                        county_fips       0.000000
# 6    2020                                         state_fips       0.000000
# 4    2020                                        county_fips       0.000000
# 3    2021                                              state       0.000000
# 2    2020                                              state       0.000000
# 7    2021                                         state_fips       0.000000
# 1    2021                                             county       0.000000
# 8    2020                                          n_inflows       0.000000
# 9    2021                                          n_inflows       0.000000
# 23   2021                                            fips_id       0.000000
# 22   2020                                            fips_id       0.000000
# 21   2021                                          net_flows       0.000000
# 14   2020                                         n_outflows       0.000000
# 15   2021                                         n_outflows       0.000000
# 20   2020                                          net_flows       0.000000
# 0    2020                                             county       0.000000

# %%
df.to_csv("7. Cleaned Datasets/final_merged_data.csv")
